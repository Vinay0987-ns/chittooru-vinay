# %%
#first importing

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score

# %%
#import the dataset
data=pd.read_csv("students.csv")

# %%
#check the data
data.head(20)
# Out:
#     Hours  Marks
# 0     2.5     21
# 1     5.1     47
# 2     3.2     27
# 3     8.5     75
# 4     3.5     30
# 5     1.5     20
# 6     9.2     88
# 7     5.5     60
# 8     8.3     81
# 9     2.7     25
# 10    7.7     85
# 11    5.9     62
# 12    4.5     41
# 13    3.3     42
# 14    1.1     17

# %%
#checking null value in the data set
print(data.isnull().sum())
# Out:
# Hours    0
# Marks    0
# dtype: int64

# %%
#split the data.the two parts of the data are splitted into 4 ,because in x both train data and test data and y also train data and testb data 
x=data[["Hours"]]
y=data["Marks"]
x_train ,x_test ,y_train ,y_test = train_test_split(x,y,test_size=0.2)

# %%
#model
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#predicting
y_predict=model.predict(x_test)

# %%
#result
df=pd.DataFrame({"Actual": y_test,"Predicted": y_predict})
df
# Out:
#    Actual  Predicted
# 8      81  81.679805
# 6      88  90.284269
# 1      47  51.086153

# %%
print("mean_absolute_error",mean_absolute_error(y_test,y_predict))
print("r2 score",r2_score(y_test,y_predict))
# Out:
# mean_absolute_error 2.350075572607821
# r2 score 0.976739433491812

# %%
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, model.predict(x), color='red', label='Regression Line')
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.legend()
plt.show()
